# %%
x = range( 11, 31 )
xtick_labels=[f"{i}:00岁" for i in x]
print(xtick_labels)
# Out:
# ['11:00岁', '12:00岁', '13:00岁', '14:00岁', '15:00岁', '16:00岁', '17:00岁', '18:00岁', '19:00岁', '20:00岁', '21:00岁', '22:00岁', '23:00岁', '24:00岁', '25:00岁', '26:00岁', '27:00岁', '28:00岁', '29:00岁', '30:00岁']
